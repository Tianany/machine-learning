# %%
import pandas as pd
# !pip install mlxtend
from mlxtend.feature_selection import SequentialFeatureSelector

# %%
df= pd.read_csv("train.csv")
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.shape
# Out:
# (2000, 21)

# %%
x = df.iloc[:, 0:20]
y = df.iloc[:,-1]

# %%
x.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=1)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
backward_feature_selector=SequentialFeatureSelector(RandomForestClassifier(n_jobs=-1),k_features=10,forward=False,floating=False,verbose=2,scoring='accuracy',cv=5).fit(x_train,y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:   56.3s finished
#
# [2024-05-29 14:43:35] Features: 19/10 -- score: 0.8857142857142858[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:   50.4s finished
#
# [2024-05-29 14:44:26] Features: 18/10 -- score: 0.8885714285714286[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:   48.1s finished
#
# [2024-05-29 14:45:14] Features: 17/10 -- score: 0.8864285714285713[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ...

# %%
backward_feature_selector.k_feature_idx_
# Out:
# (0, 2, 3, 5, 6, 9, 11, 12, 13, 16)

# %%
backward_feature_selector.k_feature_names_
# Out:
# ('battery_power',
#  'clock_speed',
#  'dual_sim',
#  'four_g',
#  'int_memory',
#  'n_cores',
#  'px_height',
#  'px_width',
#  'ram',
#  'talk_time')

# %%
backward_feature_selector.k_score_
# Out:
# 0.9021428571428572

# %%
backward_feature_selector=SequentialFeatureSelector(RandomForestClassifier(n_jobs=-1),k_features=(1,20),forward=False,floating=False,verbose=2,scoring='accuracy',cv=5).fit(x_train,y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:   57.3s finished
#
# [2024-05-29 14:58:39] Features: 19/1 -- score: 0.8778571428571429[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:   53.3s finished
#
# [2024-05-29 14:59:32] Features: 18/1 -- score: 0.8892857142857142[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:   51.5s finished
#
# [2024-05-29 15:00:24] Features: 17/1 -- score: 0.8921428571428571[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ...

# %%
backward_feature_selector.k_feature_names_
# Out:
# ('battery_power', 'mobile_wt', 'px_height', 'px_width', 'ram')

# %%
backward_feature_selector.k_score_
# Out:
# 0.9135714285714286
